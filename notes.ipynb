# %% [markdown]
# Notes:
# - Playwright
# -- Microsoft has cleared out the developers of it, might be moving back more towards selenium because it is actively being developed
#
# - system rules are implemented early to restrict the ai
# -- they are pre-prompts that dictate architecture
# --- ex: never use absolute xpath; alyways use PW async/await; strictly follow TS DTOs
#
# - ageng skills
# -- implmeneted later to give tha AI new abilities
# -- implemented via MVP the AI can autonomously call
# --- ex: github_get_pull_request
#
# The Foundation:
# - Why TS
# -- The AI Defence
# --- LLMs are notorously prone to hallucinations
#
# Interfaces
# - Best for degining objects shapes, contracts and DTOs
#
# Types
# - Best for degining unions, intersections, primitives and mapped types. They are closed and cannot be reopened to add new properties
# - no inheritance
